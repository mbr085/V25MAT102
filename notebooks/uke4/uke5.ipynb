# %% [markdown]
# # Oppgavesett 2
#
# ## Oppgave 1.
# I hvert spørsmål, bruk Python til å tegne funksjonene. Basert på
# grafen, velg en passende startverdi og finn et nullpunkt ved Newtons metode. Hvis
# funksjonen har flere nullpunkt, velg ett av dem.
# (a)
# (b)
# (c)
#
# Oppgave 2.
#
# Bruk Newtons metode på funksjonen
#
# Undersøk hva som skjer for varierende startverdier. Prøv spesielt med verdiene
#  og
#
# Oppgave 3.
#
# Bruk Newtons metode på funksjonen
#
# Hvorfor blir resultatet som det blir?
#
# Oppgave 4.
#
# Ligningen
#
# har akkurat en løsning.
#
# Forklar hvorfor ligningen har minst en løsning i intervallet [0 , 2].
# Skriv et Python-program som bruker Newtons metode til å finne løsningen nær x=1. Vi aksepterer en feilmargin på .
# Forklar hvordan vi kan være sikre på at ligningen bare har en løsning (bruk uttrykket f'(x) uten å programmere).
#
# Oppgave 5.
#
# (a) Bruk numerisk derivasjon til å finne tilnærminger til de deriverte av funksjonene fra Oppgave 1 i  og .
#
# (b) Bruk numerisk derivasjon til å tegne grafene til de deriverte av funksjonene fra Oppgave 1.

# %%
Oppgavesett 2
Oppgave 1. 
I hvert spørsmål, bruk Python til å tegne funksjonene. Basert på
grafen, velg en passende startverdi og finn et nullpunkt ved Newtons metode. Hvis
funksjonen har flere nullpunkt, velg ett av dem.
(a) 

(b) 
(c) 

Oppgave 2. 

Bruk Newtons metode på funksjonen

Undersøk hva som skjer for varierende startverdier. Prøv spesielt med verdiene
 og 

Oppgave 3. 

Bruk Newtons metode på funksjonen

Hvorfor blir resultatet som det blir?

Oppgave 4. 

Ligningen

har akkurat en løsning.

    Forklar hvorfor ligningen har minst en løsning i intervallet [0 , 2].
    Skriv et Python-program som bruker Newtons metode til å finne løsningen nær x=1. Vi aksepterer en feilmargin på 

    .
    Forklar hvordan vi kan være sikre på at ligningen bare har en løsning (bruk uttrykket f'(x) uten å programmere).

Oppgave 5. 

(a) Bruk numerisk derivasjon til å finne tilnærminger til de deriverte av funksjonene fra Oppgave 1 i 
 og 

.

(b) Bruk numerisk derivasjon til å tegne grafene til de deriverte av funksjonene fra Oppgave 1.
